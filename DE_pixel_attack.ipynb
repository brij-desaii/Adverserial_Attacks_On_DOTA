# %%
# !pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.221-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (4.12.0.88)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.16.2)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.8.0+cu126)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (0.23.0+cu126)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: polars in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.25.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.17-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2025.10.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.4.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# Downloading ultralytics-8.3.221-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 26.6 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.17-py3-none-any.whl (28 kB)
# Installing collected packages: ultralytics-thop, ultralytics
# Successfully installed ultralytics-8.3.221 ultralytics-thop-2.0.17

# %%
import os
import shutil
import glob
import numpy as np
import cv2
from tqdm import tqdm
from ultralytics import YOLO
from scipy.optimize import differential_evolution
import time
import yaml
import torch
import random
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/MN-20-Credit/Aerial-YOLO-DOTA/src
# Out:
# /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/Aerial-YOLO-DOTA/src

# %% [markdown]
# # One Pixel Attack

# %%
# =========  PATHS AND CONFIGURATION =========
MODEL_PATH      = "/content/drive/MyDrive/MN-20-Credit/models/yolov9/best.pt"
VAL_IMAGES_DIR  = "/content/drive/MyDrive/MN-20-Credit/dota-yolo/images/val"
VAL_LABELS_DIR  = "/content/drive/MyDrive/MN-20-Credit/dota-yolo/labels/val"

ATTACK_ROOT     = "/content/drive/MyDrive/MN-20-Credit/dota-yolo/de_one_pixel_attack"
ATTACK_IMG_DIR  = os.path.join(ATTACK_ROOT, "images/val")
ATTACK_LBL_DIR  = os.path.join(ATTACK_ROOT, "labels/val")

# Class names (must match training order)
NAMES = [
    "plane","ship","storage tank","baseball diamond","tennis court",
    "basketball court","ground track field","harbor","bridge","large vehicle",
    "small vehicle","helicopter","roundabout","soccer ball field","swimming pool",
    "container crane"
]

# ========= ATTACK + EVAL SETTINGS =========
IMG_SIZE      = 1024
CONF_THRES    = 0.001
DEVICE        = 0  # 'cpu' if no GPU

# DE parameters: control attack strength vs. speed
MAX_ITER      = 25  # How many "generations" the algorithm runs
POP_SIZE      = 10  # How many candidate pixels in each generation

# ========= UTILITY FUNCTIONS =========
def ensure_clean_dir(path):
    if os.path.isdir(path):
        shutil.rmtree(path)
    os.makedirs(path, exist_ok=True)

def score_image(model, img_bgr):
    """
    Black-box 'badness' score (fitness function) we want to MINIMIZE.
    Returns the sum of confidences of all detections.
    """
    res = model.predict(source=img_bgr, imgsz=IMG_SIZE, conf=CONF_THRES,
                        device=DEVICE, half=True, verbose=False)[0]
    if res.boxes is None or len(res.boxes) == 0:
        return 0.0
    return float(res.boxes.conf.sum().item())

def de_one_pixel_attack(model, img_bgr):
    """
    Finds the best single-pixel attack using Differential Evolution.
    """
    h, w, _ = img_bgr.shape
    base_score = score_image(model, img_bgr)

    # 1. Define the function for DE to MINIMIZE
    def objective_function(pixel_params):
        # pixel_params is a 1D array: [x, y, r, g, b]
        x, y, r, g, b = [int(p) for p in pixel_params]

        # Ensure coordinates are within image bounds
        x = max(0, min(w - 1, x))
        y = max(0, min(h - 1, y))

        attacked_img = img_bgr.copy()
        attacked_img[y, x] = (b, g, r)  # Use BGR for cv2

        return score_image(model, attacked_img)

    # 2. Define the BOUNDS for each parameter (x, y, r, g, b)
    bounds = [
        (0, w - 1),  # x coordinate
        (0, h - 1),  # y coordinate
        (0, 255),    # Red channel
        (0, 255),    # Green channel
        (0, 255)     # Blue channel
    ]

    # 3. Run the Differential Evolution solver
    result = differential_evolution(
        func=objective_function,
        bounds=bounds,
        maxiter=MAX_ITER,
        popsize=POP_SIZE,
        disp=False
    )

    # 4. Extract the best attack and create the final image
    best_pixel = result.x.astype(int)
    final_attack_img = img_bgr.copy()
    x, y, r, g, b = best_pixel
    x = max(0, min(w - 1, x))
    y = max(0, min(h - 1, y))
    final_attack_img[y, x] = (b, g, r)

    attacked_score = result.fun  # The score of the best solution found

    return final_attack_img, attacked_score, base_score

# ========= SCRIPT EXECUTION =========
ensure_clean_dir(ATTACK_IMG_DIR)
ensure_clean_dir(ATTACK_LBL_DIR)

# Copy labels to the new attack directory
print("Copying labels...")
for p in glob.glob(os.path.join(VAL_LABELS_DIR, "*.txt")):
    shutil.copy2(p, ATTACK_LBL_DIR)

print("Loading model...")
model = YOLO(MODEL_PATH)

exts = (".jpg", ".jpeg", ".png", ".bmp", ".tif", ".tiff")
img_paths = [p for p in glob.glob(os.path.join(VAL_IMAGES_DIR, "*")) if p.lower().endswith(exts)]
per_image_scores = []

print("Starting DE one-pixel attack...")
for ip in tqdm(img_paths, desc="DE One-pixel attacking"):
    img = cv2.imread(ip)
    if img is None:
        continue

    attacked, attacked_score, base_score = de_one_pixel_attack(model, img)

    base_name = os.path.basename(ip)
    cv2.imwrite(os.path.join(ATTACK_IMG_DIR, base_name), attacked)
    per_image_scores.append((base_name, base_score, attacked_score))

print(f"\n[OK] Saved attacked images to: {ATTACK_IMG_DIR}")

print("\nPausing for 15 seconds to allow file system to sync...")
time.sleep(15)

# Optional: Print the average score drop
drops = [b - a for _, b, a in per_image_scores if b > 0] # Avoid division by zero
if drops:
    print(f"Proxy score drop (mean) over {len(drops)} images: {np.mean(drops):.4f}")

# ========= FINAL EVALUATION =========
print("\nRunning evaluation on the attacked dataset...")
import yaml
DATA_YAML = "/content/de_attacked_tmp.yaml"
with open(DATA_YAML, "w") as f:
    yaml.safe_dump({
        "path": ATTACK_ROOT,
        "train": "images/val",
        "val": "images/val",
        "names": {i: n for i, n in enumerate(NAMES)},
        "nc": len(NAMES)
    }, f, sort_keys=False)

metrics_attack = model.val(
    data=DATA_YAML,
    split="val",
    imgsz=IMG_SIZE,
    conf=CONF_THRES,
    iou=0.5,
    device=DEVICE,
    half=True,
    verbose=False
)

print("\n== DE ATTACKED SET RESULTS ==")
print(f"mAP@0.50      : {metrics_attack.box.map50:.4f}")
print(f"mAP@0.50:0.95 : {metrics_attack.box.map:.4f}")
print(f"Precision     : {metrics_attack.box.mp:.4f}")
print(f"Recall        : {metrics_attack.box.mr:.4f}")
# Out:
# Copying labels...
# Loading model...
# Starting DE one-pixel attack...
# DE One-pixel attacking:  78%|███████▊  | 293/374 [2:05:58<28:02, 20.77s/it]
# WARNING ⚠️ NMS time limit 2.050s exceeded
# DE One-pixel attacking: 100%|██████████| 374/374 [2:39:36<00:00, 25.61s/it]
# [OK] Saved attacked images to: /content/drive/MyDrive/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val
#
# Pausing for 15 seconds to allow file system to sync...
# Proxy score drop (mean) over 374 images: 0.0739
#
# Running evaluation on the attacked dataset...
# Ultralytics 8.3.209 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 113.1MB/s 0.0s
# val: Fast image access ✅ (ping: 9.6±20.2 ms, read: 191.5±177.7 MB/s, size: 20069.3 KB)
# val: Scanning /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/labels/val... 374 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 374/374 20.9it/s 17.9s
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0003.png: 55 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0011.png: 92 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0020.png: 924 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0023.png: 1663 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0027.png: 44 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0032.png: 56 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0042.png: 60 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0053.png: 109 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0056.png: 27 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0076.png: 3 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0098.png: 96 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0099.png: 50 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0131.png: 216 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0133.png: 175 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0142.png: 15 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0152.png: 214 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0160.png: 1932 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0161.png: 1540 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0171.png: 54 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0176.png: 10 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0178.png: 36 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0187.png: 73 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0190.png: 589 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0198.png: 19 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0199.png: 82 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0201.png: 46 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0203.png: 10 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0210.png: 51 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0215.png: 39 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0217.png: 39 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0221.png: 179 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0225.png: 27 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0233.png: 84 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0236.png: 49 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0251.png: 64 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0259.png: 131 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0294.png: 13 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0299.png: 275 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0310.png: 22 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0330.png: 60 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0332.png: 34 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0334.png: 60 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0338.png: 25 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0344.png: 21 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0348.png: 6 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0353.png: 60 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0366.png: 23 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0367.png: 19 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0373.png: 30 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0375.png: 56 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0381.png: 43 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0388.png: 14 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0392.png: 9 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0417.png: 21 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0425.png: 18 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0432.png: 15 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0437.png: 16 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0441.png: 15 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0443.png: 15 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0464.png: 106 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0468.png: 23 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0469.png: 7 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0475.png: 122 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0481.png: 5 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0491.png: 7 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0505.png: 23 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0542.png: 11 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0544.png: 12 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0555.png: 17 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0558.png: 10 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0563.png: 8 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0564.png: 10 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0577.png: 8 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0579.png: 11 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0593.png: 6 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0595.png: 11 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0612.png: 56 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0624.png: 18 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0630.png: 21 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0632.png: 14 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0638.png: 4 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0641.png: 9 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0642.png: 11 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0653.png: 94 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0656.png: 5 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0664.png: 10 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0668.png: 6 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0673.png: 11 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0684.png: 15 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0685.png: 415 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0687.png: 104 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0689.png: 17 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0695.png: 561 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0703.png: 326 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0704.png: 337 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0706.png: 663 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0707.png: 101 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0732.png: 190 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0745.png: 40 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0753.png: 24 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0761.png: 115 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0775.png: 1160 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0777.png: 802 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0782.png: 12 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0789.png: 316 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0800.png: 302 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0851.png: 13 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0857.png: 110 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0860.png: 1300 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0864.png: 708 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0867.png: 570 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0883.png: 27 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0890.png: 655 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0895.png: 211 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0908.png: 43 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0913.png: 45 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0914.png: 50 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0921.png: 62 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0922.png: 22 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0925.png: 20 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0926.png: 57 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0934.png: 162 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0940.png: 126 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0944.png: 83 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0974.png: 11 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0977.png: 28 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P0987.png: 15 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1014.png: 342 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1019.png: 1127 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1022.png: 15 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1027.png: 155 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1043.png: 26 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1059.png: 196 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1061.png: 34 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1065.png: 99 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1076.png: 467 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1088.png: 34 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1089.png: 9 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1095.png: 57 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1134.png: 3 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1141.png: 22 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1143.png: 38 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1144.png: 7 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1149.png: 17 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1155.png: 12 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1165.png: 105 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1186.png: 64 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1187.png: 123 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1191.png: 57 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1200.png: 6 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1211.png: 1 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1214.png: 73 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1224.png: 35 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1225.png: 21 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1242.png: 293 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1245.png: 18 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1247.png: 40 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1258.png: 30 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1260.png: 21 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1269.png: 32 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1291.png: 3 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1292.png: 3 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1298.png: 2 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1306.png: 12 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1307.png: 16 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1322.png: 43 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1333.png: 36 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1338.png: 44 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1344.png: 87 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1353.png: 65 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1354.png: 123 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1356.png: 101 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1364.png: 5 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1366.png: 49 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1370.png: 5 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1373.png: 68 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1374.png: 1915 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1386.png: 218 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1408.png: 605 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1421.png: 16 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1426.png: 55 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1429.png: 23 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1437.png: 20 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1439.png: 109 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1443.png: 47 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1444.png: 179 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1458.png: 209 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1466.png: 859 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1469.png: 139 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1471.png: 636 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1476.png: 60 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1482.png: 103 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1484.png: 26 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1499.png: 303 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1507.png: 23 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1509.png: 49 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1518.png: 5 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1521.png: 11 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1524.png: 5 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1529.png: 17 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1533.png: 2 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1534.png: 3 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1545.png: 29 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1560.png: 4 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1562.png: 35 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1563.png: 23 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1565.png: 5 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1582.png: 4 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1596.png: 3 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1598.png: 36 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1600.png: 3 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1604.png: 12 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1609.png: 22 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1631.png: 11 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1639.png: 19 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1656.png: 34 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1669.png: 5 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1670.png: 40 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1673.png: 8 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1674.png: 1 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1682.png: 2 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1683.png: 1 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1689.png: 1 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1697.png: 6 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1699.png: 1 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1702.png: 5 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1703.png: 2 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1705.png: 4 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1713.png: 16 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1717.png: 1 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1744.png: 30 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1751.png: 16 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1759.png: 2 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1765.png: 35 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1778.png: 429 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1779.png: 31 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1786.png: 614 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1789.png: 72 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1808.png: 85 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1818.png: 86 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1822.png: 42 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1841.png: 133 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1843.png: 42 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1846.png: 98 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1866.png: 353 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1876.png: 30 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1877.png: 110 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1879.png: 12 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1892.png: 147 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1896.png: 141 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1905.png: 60 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1907.png: 182 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1910.png: 13 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1912.png: 70 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1913.png: 90 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1918.png: 27 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1919.png: 22 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1924.png: 43 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1938.png: 130 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1939.png: 243 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1940.png: 193 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1951.png: 236 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1957.png: 193 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1959.png: 84 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1965.png: 97 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1982.png: 142 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1983.png: 299 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1989.png: 159 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1995.png: 106 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1997.png: 200 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P1998.png: 55 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2005.png: 557 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2006.png: 418 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2007.png: 889 duplicate labels removed
# ...
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2057.png: 27 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2062.png: 153 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2063.png: 148 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2065.png: 192 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2067.png: 23 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2079.png: 51 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2087.png: 44 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2097.png: 717 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2111.png: 43 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2115.png: 14 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2126.png: 94 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2134.png: 11 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2135.png: 55 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2150.png: 26 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2156.png: 167 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2163.png: 72 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2168.png: 40 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2173.png: 179 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2177.png: 6 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2189.png: 1 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2197.png: 212 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2210.png: 282 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2218.png: 13 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2225.png: 78 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2228.png: 57 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2230.png: 263 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2232.png: 170 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2234.png: 55 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2236.png: 54 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2253.png: 104 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2255.png: 7 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2281.png: 87 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2289.png: 4 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2294.png: 4 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2313.png: 20 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2332.png: 27 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2348.png: 604 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2351.png: 4 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2354.png: 2 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2363.png: 5 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2368.png: 9 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2389.png: 3 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2390.png: 1 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2397.png: 24 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2401.png: 19 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2417.png: 4 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2426.png: 5 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2436.png: 4 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2454.png: 94 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2460.png: 346 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2464.png: 27 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2468.png: 3 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2477.png: 2 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2492.png: 4 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2516.png: 1 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2522.png: 9 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2528.png: 1 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2534.png: 3 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2543.png: 32 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2545.png: 1 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2551.png: 75 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2558.png: 46 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2569.png: 31 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2590.png: 9 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2593.png: 57 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2594.png: 15 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2597.png: 22 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2622.png: 92 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2639.png: 48 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2642.png: 518 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2650.png: 43 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2657.png: 26 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2668.png: 683 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2669.png: 58 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2670.png: 1872 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2674.png: 171 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2678.png: 200 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2685.png: 34 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2686.png: 634 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2690.png: 123 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2693.png: 137 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2701.png: 401 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2722.png: 25 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2727.png: 37 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2754.png: 1666 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2768.png: 15 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2787.png: 396 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2797.png: 12 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/images/val/P2804.png: 652 duplicate labels removed
# val: New cache created: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_one_pixel_attack/labels/val.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 24/24 0.3it/s 1:18
#                    all        374      53258       0.84      0.656      0.714      0.555
# Speed: 2.3ms preprocess, 98.7ms inference, 0.0ms loss, 6.5ms postprocess per image
# Results saved to /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/Aerial-YOLO-DOTA/src/runs/detect/val44
#
# == DE ATTACKED SET RESULTS ==
# mAP@0.50      : 0.7141
# mAP@0.50:0.95 : 0.5548
# Precision     : 0.8401
# Recall        : 0.6562

# %% [markdown]
# # 3 Pixel Attack

# %%
import os
import shutil
import glob
import time
import cv2
import yaml
import numpy as np
from tqdm import tqdm
from ultralytics import YOLO
from scipy.optimize import differential_evolution
import torch
import random

# ========= USER CONFIG (edit these paths if needed) =========
MODEL_PATH = "/content/drive/MyDrive/MN-20-Credit/models/yolov9/best.pt"
VAL_IMAGES_DIR = "/content/drive/MyDrive/MN-20-Credit/dota-yolo/images/val"
VAL_LABELS_DIR = "/content/drive/MyDrive/MN-20-Credit/dota-yolo/labels/val"

ATTACK_ROOT = "/content/drive/MyDrive/MN-20-Credit/dota-yolo/de_three_pixel_attack"
# inside ATTACK_ROOT we'll create:
# - baseline/images/val  (sampled originals)
# - baseline/preds       (baseline annotated images)
# - images/val           (attacked images)
# - labels/val           (copied labels for attacked set)
# - attacked_preds       (annotated attacked images)

# class names (map index->name)
NAMES = [
    "plane","ship","storage tank","baseball diamond","tennis court",
    "basketball court","ground track field","harbor","bridge","large vehicle",
    "small vehicle","helicopter","roundabout","soccer ball field","swimming pool",
    "container crane"
]

# ========= ATTACK + EVAL SETTINGS =========
IMG_SIZE = 1024
CONF_THRES = 0.001

# Device and half-precision
USE_CUDA = torch.cuda.is_available()
DEVICE = "cuda" if USE_CUDA else "cpu"
HALF = USE_CUDA
print(f"[INFO] Using device: {DEVICE}, half precision: {HALF}")

# DE parameters
MAX_ITER = 30
POP_SIZE = 20
DE_SEED = 42
DE_WORKERS = 1

# ========= REPRODUCIBILITY =========
random.seed(DE_SEED)
np.random.seed(DE_SEED)
torch.manual_seed(DE_SEED)
if USE_CUDA:
    torch.cuda.manual_seed_all(DE_SEED)
    torch.backends.cudnn.benchmark = True

# ========= UTILITY FUNCTIONS =========

def ensure_clean_dir(path):
    if os.path.isdir(path):
        shutil.rmtree(path)
    os.makedirs(path, exist_ok=True)


def score_image(model, img_bgr):
    try:
        res = model.predict(source=img_bgr, imgsz=IMG_SIZE, conf=CONF_THRES,
                            device=DEVICE, half=HALF, verbose=False)[0]
    except Exception:
        res = model.predict(source=img_bgr, imgsz=IMG_SIZE, conf=CONF_THRES,
                            device="cpu", half=False, verbose=False)[0]
    if getattr(res, "boxes", None) is None or len(res.boxes) == 0:
        return 0.0
    confs = getattr(res.boxes, "conf", None)
    if confs is None:
        return 0.0
    try:
        s = float(confs.sum().item())
    except Exception:
        s = float(np.array(confs).sum())
    return s


# DE three-pixel attack (returns attacked_img, attacked_score, base_score)
def de_three_pixel_attack(model, img_bgr, maxiter=MAX_ITER, popsize=POP_SIZE, seed=DE_SEED, workers=DE_WORKERS):
    h, w, _ = img_bgr.shape
    base_score = score_image(model, img_bgr)

    pixel_bounds = [(0, w - 1), (0, h - 1), (0, 255), (0, 255), (0, 255)]
    bounds = pixel_bounds * 3  # 3 pixels = 15 params

    # lightweight progress display
    from tqdm import tqdm as _tqdm
    pbar = _tqdm(total=maxiter, desc="DE generations", leave=False)

    def callback_progress(xk, convergence):
        try:
            pbar.update(1)
        except Exception:
            pass
        return False

    def objective_function(params):
        attacked_img = img_bgr.copy()
        for i in range(3):
            offset = i * 5
            x = int(np.round(params[offset + 0])); x = int(np.clip(x, 0, w - 1))
            y = int(np.round(params[offset + 1])); y = int(np.clip(y, 0, h - 1))
            r = int(np.clip(int(np.round(params[offset + 2])), 0, 255))
            g = int(np.clip(int(np.round(params[offset + 3])), 0, 255))
            b = int(np.clip(int(np.round(params[offset + 4])), 0, 255))
            attacked_img[y, x] = [b, g, r]
        return score_image(model, attacked_img)

    # try multiprocess workers, fallback to single
    result = None
    for attempt_workers in (workers, 1):
        try:
            result = differential_evolution(
                func=objective_function,
                bounds=bounds,
                maxiter=maxiter,
                popsize=popsize,
                seed=seed,
                disp=False,
                polish=True,
                workers=attempt_workers,
                callback=callback_progress
            )
            break
        except Exception as e:
            if attempt_workers == 1:
                pbar.close()
                raise
            else:
                print(f"[WARN] differential_evolution with workers={attempt_workers} failed: {e}. Retrying with workers=1...")
                pbar.close()
                time.sleep(1)

    pbar.close()

    best_params = result.x
    final_attack_img = img_bgr.copy()
    for i in range(3):
        offset = i * 5
        x = int(np.clip(int(np.round(best_params[offset + 0])), 0, w - 1))
        y = int(np.clip(int(np.round(best_params[offset + 1])), 0, h - 1))
        r = int(np.clip(int(np.round(best_params[offset + 2])), 0, 255))
        g = int(np.clip(int(np.round(best_params[offset + 3])), 0, 255))
        b = int(np.clip(int(np.round(best_params[offset + 4])), 0, 255))
        final_attack_img[y, x] = [b, g, r]

    attacked_score = float(result.fun)
    return final_attack_img, attacked_score, base_score


# ========= SCRIPT EXECUTION =========

# Prepare directories
ensure_clean_dir(ATTACK_ROOT)
BASELINE_ROOT = os.path.join(ATTACK_ROOT, "baseline")
ATTACK_IMG_DIR = os.path.join(ATTACK_ROOT, "images/val")
ATTACK_LBL_DIR = os.path.join(ATTACK_ROOT, "labels/val")
BASELINE_IMG_DIR = os.path.join(BASELINE_ROOT, "images/val")
BASELINE_LBL_DIR = os.path.join(BASELINE_ROOT, "labels/val")
BASELINE_PRED_DIR = os.path.join(BASELINE_ROOT, "preds")
ATTACKED_PRED_DIR = os.path.join(ATTACK_ROOT, "attacked_preds")

for d in (BASELINE_IMG_DIR, BASELINE_LBL_DIR, BASELINE_PRED_DIR, ATTACK_IMG_DIR, ATTACK_LBL_DIR, ATTACKED_PRED_DIR):
    os.makedirs(d, exist_ok=True)

print("Loading model...")
model = YOLO(MODEL_PATH)

# free some GPU memory (if using GPU)
if USE_CUDA:
    torch.cuda.empty_cache()

exts = (".jpg", ".jpeg", ".png", ".bmp", ".tif", ".tiff")
all_img_paths = [p for p in glob.glob(os.path.join(VAL_IMAGES_DIR, "*")) if p.lower().endswith(exts)]

random.shuffle(all_img_paths)
num_to_test = max(1, int(len(all_img_paths) * 0.05))
sampled_img_paths = all_img_paths[:num_to_test]
print(f"[INFO] A random 5% sample will be tested: {len(sampled_img_paths)} images.\n")

# Copy corresponding labels and images into baseline and copy labels into ATTACK_LBL_DIR for attacked set
for img_p in sampled_img_paths:
    base = os.path.basename(img_p)
    lbl_name = os.path.splitext(base)[0] + ".txt"
    src_lbl = os.path.join(VAL_LABELS_DIR, lbl_name)
    # copy image -> baseline images
    shutil.copy2(img_p, os.path.join(BASELINE_IMG_DIR, base))
    # copy label -> baseline labels (if existing)
    if os.path.exists(src_lbl):
        shutil.copy2(src_lbl, os.path.join(BASELINE_LBL_DIR, lbl_name))
        shutil.copy2(src_lbl, os.path.join(ATTACK_LBL_DIR, lbl_name))

# ========= Baseline per-image predictions (annotated) =========
print("Running baseline per-image predictions and saving annotated images...")
for img_p in tqdm(sampled_img_paths, desc="Baseline preds"):
    img = cv2.imread(img_p)
    if img is None:
        continue
    # predict once and save annotated image
    try:
        res = model.predict(source=img, imgsz=IMG_SIZE, conf=CONF_THRES, device=DEVICE, half=HALF, verbose=False)[0]
    except Exception:
        res = model.predict(source=img, imgsz=IMG_SIZE, conf=CONF_THRES, device="cpu", half=False, verbose=False)[0]
    ann = res.plot()  # annotated image as BGR
    cv2.imwrite(os.path.join(BASELINE_PRED_DIR, os.path.basename(img_p)), ann)

# Baseline evaluation using ultralytics val() on the sampled set
DATA_YAML_BASE = os.path.join(ATTACK_ROOT, "de_baseline_tmp.yaml")
with open(DATA_YAML_BASE, "w") as f:
    yaml.safe_dump({
        "path": BASELINE_ROOT,
        "train": "images/val",
        "val": "images/val",
        "names": {i: n for i, n in enumerate(NAMES)},
        "nc": len(NAMES)
    }, f, sort_keys=False)

print("\nEvaluating baseline (sampled 5%) with model.val()...")
metrics_base = model.val(data=DATA_YAML_BASE, split="val", imgsz=IMG_SIZE, conf=CONF_THRES,
                         iou=0.5, device=DEVICE, half=HALF, verbose=False)

base_map50 = float(metrics_base.box.map50)
base_map = float(metrics_base.box.map)
base_prec = float(metrics_base.box.mp)
base_rec = float(metrics_base.box.mr)

print("\n== BASELINE (SAMPLED 5%) RESULTS ==")
print(f"mAP@0.50 : {base_map50:.4f}")
print(f"mAP@0.50:0.95 : {base_map:.4f}")
print(f"Precision : {base_prec:.4f}")
print(f"Recall : {base_rec:.4f}")

# ========= RUN ATTACK ON SAMPLED IMAGES =========
print("\nStarting DE three-pixel attack on sampled images...")
per_image_scores = []
for ip in tqdm(sampled_img_paths, desc="Attacking images"):
    img = cv2.imread(ip)
    if img is None:
        continue

    attacked, attacked_score, base_score = de_three_pixel_attack(
        model, img, maxiter=MAX_ITER, popsize=POP_SIZE, seed=DE_SEED, workers=DE_WORKERS
    )

    base_name = os.path.basename(ip)
    # save attacked image
    cv2.imwrite(os.path.join(ATTACK_IMG_DIR, base_name), attacked)
    per_image_scores.append((base_name, base_score, attacked_score))

print(f"\n[OK] Saved attacked images to: {ATTACK_IMG_DIR}")
print("\nPausing briefly to allow file system to sync...")
time.sleep(5)

# compute proxy drops
drops = [base - attacked for _, base, attacked in per_image_scores if base > 0]
if drops:
    print(f"Proxy score drop (mean) over {len(drops)} images: {np.mean(drops):.4f}")

# ========= Attacked predictions (annotated) =========
print("\nRunning predictions on attacked images and saving annotated images...")
attacked_img_paths = [os.path.join(ATTACK_IMG_DIR, os.path.basename(x)) for x in sampled_img_paths]
for aip in tqdm(attacked_img_paths, desc="Attacked preds"):
    img = cv2.imread(aip)
    if img is None:
        continue
    try:
        res = model.predict(source=img, imgsz=IMG_SIZE, conf=CONF_THRES, device=DEVICE, half=HALF, verbose=False)[0]
    except Exception:
        res = model.predict(source=img, imgsz=IMG_SIZE, conf=CONF_THRES, device="cpu", half=False, verbose=False)[0]
    ann = res.plot()
    cv2.imwrite(os.path.join(ATTACKED_PRED_DIR, os.path.basename(aip)), ann)

# ========= EVALUATION ON ATTACKED SET =========
DATA_YAML_ATTACK = os.path.join(ATTACK_ROOT, "de_attacked_tmp.yaml")
with open(DATA_YAML_ATTACK, "w") as f:
    yaml.safe_dump({
        "path": ATTACK_ROOT,
        "train": "images/val",
        "val": "images/val",
        "names": {i: n for i, n in enumerate(NAMES)},
        "nc": len(NAMES)
    }, f, sort_keys=False)

print("\nEvaluating attacked set with model.val()...")
metrics_attack = model.val(data=DATA_YAML_ATTACK, split="val", imgsz=IMG_SIZE, conf=CONF_THRES,
                           iou=0.5, device=DEVICE, half=HALF, verbose=False)

atk_map50 = float(metrics_attack.box.map50)
atk_map = float(metrics_attack.box.map)
atk_prec = float(metrics_attack.box.mp)
atk_rec = float(metrics_attack.box.mr)

print("\n== DE ATTACKED SET RESULTS ==")
print(f"mAP@0.50 : {atk_map50:.4f}")
print(f"mAP@0.50:0.95 : {atk_map:.4f}")
print(f"Precision : {atk_prec:.4f}")
print(f"Recall : {atk_rec:.4f}")

# ========= COMPARISON SUMMARY =========
print("\n== SUMMARY (Baseline vs Attacked on sampled 5%) ==")
print(f"mAP@0.50 : baseline={base_map50:.4f}  |  attacked={atk_map50:.4f}  |  drop={base_map50 - atk_map50:.4f}")
print(f"mAP@0.50:0.95 : baseline={base_map:.4f}  |  attacked={atk_map:.4f}  |  drop={base_map - atk_map:.4f}")
print(f"Precision : baseline={base_prec:.4f}  |  attacked={atk_prec:.4f}  |  drop={base_prec - atk_prec:.4f}")
print(f"Recall : baseline={base_rec:.4f}  |  attacked={atk_rec:.4f}  |  drop={base_rec - atk_rec:.4f}")

# Save per-image proxy drops CSV
csv_out = os.path.join(ATTACK_ROOT, "per_image_proxy_scores.csv")
with open(csv_out, "w") as f:
    f.write("image,base_score,attacked_score,drop\n")
    for base_name, base_score, attacked_score in per_image_scores:
        f.write(f"{base_name},{base_score:.6f},{attacked_score:.6f},{(base_score-attacked_score):.6f}\n")

print(f"\nPer-image proxy scores written to: {csv_out}")
print(f"Annotated baseline preds: {BASELINE_PRED_DIR}")
print(f"Annotated attacked preds: {ATTACKED_PRED_DIR}")

print("\nDone.")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# [INFO] Using device: cuda, half precision: True
# Loading model...
# [INFO] A random 5% sample will be tested: 18 images.
#
# Running baseline per-image predictions and saving annotated images...
# Baseline preds: 100%|██████████| 18/18 [00:28<00:00,  1.59s/it]
# Evaluating baseline (sampled 5%) with model.val()...
# Ultralytics 8.3.221 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 17.4MB/s 0.0s
# val: Fast image access ✅ (ping: 0.9±0.4 ms, read: 481.5±159.6 MB/s, size: 6726.2 KB)
# val: Scanning /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_three_pixel_attack/baseline/labels/val... 18 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 18/18 42.6it/s 0.4s
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_three_pixel_attack/baseline/images/val/P0042.png: 60 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_three_pixel_attack/baseline/images/val/P0217.png: 39 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_three_pixel_attack/baseline/images/val/P0233.png: 84 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_three_pixel_attack/baseline/images/val/P0294.png: 13 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_three_pixel_attack/baseline/images/val/P0366.png: 23 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_three_pixel_attack/baseline/images/val/P0913.png: 45 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_three_pixel_attack/baseline/images/val/P1022.png: 15 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_three_pixel_attack/baseline/images/val/P1225.png: 21 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_three_pixel_attack/baseline/images/val/P1260.png: 21 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_three_pixel_attack/baseline/images/val/P1482.png: 103 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_three_pixel_attack/baseline/images/val/P1596.png: 3 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_three_pixel_attack/baseline/images/val/P1670.png: 40 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_three_pixel_attack/baseline/images/val/P1697.png: 6 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_three_pixel_attack/baseline/images/val/P1751.png: 16 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_three_pixel_attack/baseline/images/val/P1997.png: 200 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_three_pixel_attack/baseline/images/val/P1998.png: 55 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_three_pixel_attack/baseline/images/val/P2787.png: 396 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_three_pixel_attack/baseline/images/val/P2804.png: 652 duplicate labels removed
# val: New cache created: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_three_pixel_attack/baseline/labels/val.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.1it/s 16.3s
#                    all         18       1792      0.833      0.518      0.617      0.432
# Speed: 14.0ms preprocess, 595.5ms inference, 0.0ms loss, 6.2ms postprocess per image
# Results saved to /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/Aerial-YOLO-DOTA/src/runs/detect/val47
#
# == BASELINE (SAMPLED 5%) RESULTS ==
# mAP@0.50 : 0.6172
# mAP@0.50:0.95 : 0.4320
# Precision : 0.8332
# Recall : 0.5176
#
# Starting DE three-pixel attack on sampled images...
# Attacking images:   0%|          | 0/18 [00:00<?, ?it/s]
# DE generations:   0%|          | 0/30 [00:00<?, ?it/s]
# DE generations:   3%|▎         | 1/30 [00:43<21:11, 43.84s/it]
# Attacking images:   6%|▌         | 1/18 [00:45<12:49, 45.29s/it]
# DE generations:   0%|          | 0/30 [00:00<?, ?it/s]
# DE generations:   3%|▎         | 1/30 [00:47<22:54, 47.39s/it]
# Attacking images:  11%|█         | 2/18 [01:34<12:44, 47.81s/it]
# DE generations:   0%|          | 0/30 [00:00<?, ?it/s]
# DE generations:   3%|▎         | 1/30 [00:55<26:41, 55.21s/it]
# Attacking images:  17%|█▋        | 3/18 [02:32<13:06, 52.46s/it]
# DE generations:   0%|          | 0/30 [00:00<?, ?it/s]
# DE generations:   3%|▎         | 1/30 [00:35<17:17, 35.77s/it]
# Attacking images:  22%|██▏       | 4/18 [03:09<10:48, 46.32s/it]
# DE generations:   0%|          | 0/30 [00:00<?, ?it/s]
# DE generations:   3%|▎         | 1/30 [00:23<11:28, 23.75s/it]
# Attacking images:  28%|██▊       | 5/18 [03:34<08:21, 38.55s/it]
# DE generations:   0%|          | 0/30 [00:00<?, ?it/s]
# DE generations:   3%|▎         | 1/30 [00:43<20:47, 43.01s/it]
# Attacking images:  33%|███▎      | 6/18 [04:19<08:07, 40.59s/it]
# DE generations:   0%|          | 0/30 [00:00<?, ?it/s]
# DE generations:   3%|▎         | 1/30 [00:39<18:55, 39.14s/it]
# Attacking images:  39%|███▉      | 7/18 [04:59<07:25, 40.54s/it]
# DE generations:   0%|          | 0/30 [00:00<?, ?it/s]
# DE generations:   3%|▎         | 1/30 [00:55<26:46, 55.39s/it]
# Attacking images:  44%|████▍     | 8/18 [05:57<07:41, 46.14s/it]
# DE generations:   0%|          | 0/30 [00:00<?, ?it/s]
# DE generations:   3%|▎         | 1/30 [00:55<26:48, 55.48s/it]
# Attacking images:  50%|█████     | 9/18 [06:55<07:29, 49.90s/it]
# DE generations:   0%|          | 0/30 [00:00<?, ?it/s]
# DE generations:   3%|▎         | 1/30 [00:36<17:36, 36.41s/it]
# Attacking images:  56%|█████▌    | 10/18 [07:33<06:08, 46.07s/it]
# DE generations:   0%|          | 0/30 [00:00<?, ?it/s]
# DE generations:   3%|▎         | 1/30 [00:55<26:50, 55.55s/it]
# Attacking images:  61%|██████    | 11/18 [08:31<05:49, 49.91s/it]
# DE generations:   0%|          | 0/30 [00:00<?, ?it/s]
# DE generations:   3%|▎         | 1/30 [00:50<24:17, 50.27s/it]
# Attacking images:  67%|██████▋   | 12/18 [09:25<05:05, 50.89s/it]
# DE generations:   0%|          | 0/30 [00:00<?, ?it/s]
# DE generations:   3%|▎         | 1/30 [00:31<15:13, 31.49s/it]
# Attacking images:  72%|███████▏  | 13/18 [09:58<03:47, 45.54s/it]
# DE generations:   0%|          | 0/30 [00:00<?, ?it/s]
# DE generations:   3%|▎         | 1/30 [00:36<17:47, 36.83s/it]
# Attacking images:  78%|███████▊  | 14/18 [10:36<02:53, 43.45s/it]
# DE generations:   0%|          | 0/30 [00:00<?, ?it/s]
# DE generations:   3%|▎         | 1/30 [00:56<27:18, 56.50s/it]
# Attacking images:  83%|████████▎ | 15/18 [11:36<02:24, 48.28s/it]
# DE generations:   0%|          | 0/30 [00:00<?, ?it/s]
# DE generations:   3%|▎         | 1/30 [00:41<20:15, 41.90s/it]
# Attacking images:  89%|████████▉ | 16/18 [12:20<01:33, 46.87s/it]
# DE generations:   0%|          | 0/30 [00:00<?, ?it/s]
# DE generations:   3%|▎         | 1/30 [00:28<13:49, 28.61s/it]
# Attacking images:  94%|█████████▍| 17/18 [12:50<00:41, 41.88s/it]
# DE generations:   0%|          | 0/30 [00:00<?, ?it/s]
# DE generations:   3%|▎         | 1/30 [00:40<19:32, 40.42s/it]
# Attacking images: 100%|██████████| 18/18 [13:32<00:00, 45.11s/it]
# [OK] Saved attacked images to: /content/drive/MyDrive/MN-20-Credit/dota-yolo/de_three_pixel_attack/images/val
#
# Pausing briefly to allow file system to sync...
# Proxy score drop (mean) over 18 images: 0.1613
#
# Running predictions on attacked images and saving annotated images...
# Attacked preds: 100%|██████████| 18/18 [00:16<00:00,  1.08it/s]
# Evaluating attacked set with model.val()...
# Ultralytics 8.3.221 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.6±0.2 ms, read: 589.5±187.6 MB/s, size: 10553.1 KB)
# val: Scanning /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_three_pixel_attack/labels/val... 18 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 18/18 34.9it/s 0.5s
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_three_pixel_attack/images/val/P0042.png: 60 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_three_pixel_attack/images/val/P0217.png: 39 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_three_pixel_attack/images/val/P0233.png: 84 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_three_pixel_attack/images/val/P0294.png: 13 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_three_pixel_attack/images/val/P0366.png: 23 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_three_pixel_attack/images/val/P0913.png: 45 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_three_pixel_attack/images/val/P1022.png: 15 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_three_pixel_attack/images/val/P1225.png: 21 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_three_pixel_attack/images/val/P1260.png: 21 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_three_pixel_attack/images/val/P1482.png: 103 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_three_pixel_attack/images/val/P1596.png: 3 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_three_pixel_attack/images/val/P1670.png: 40 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_three_pixel_attack/images/val/P1697.png: 6 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_three_pixel_attack/images/val/P1751.png: 16 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_three_pixel_attack/images/val/P1997.png: 200 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_three_pixel_attack/images/val/P1998.png: 55 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_three_pixel_attack/images/val/P2787.png: 396 duplicate labels removed
# val: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_three_pixel_attack/images/val/P2804.png: 652 duplicate labels removed
# val: New cache created: /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/dota-yolo/de_three_pixel_attack/labels/val.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.3it/s 6.4s
#                    all         18       1792      0.827      0.512       0.61      0.431
# Speed: 17.3ms preprocess, 84.9ms inference, 0.0ms loss, 2.5ms postprocess per image
# Results saved to /content/drive/.shortcut-targets-by-id/1zpTDLsM5hxDp5YzIh-V3E0q2h9S7058N/MN-20-Credit/Aerial-YOLO-DOTA/src/runs/detect/val48
#
# == DE ATTACKED SET RESULTS ==
# mAP@0.50 : 0.6100
# mAP@0.50:0.95 : 0.4313
# Precision : 0.8265
# Recall : 0.5122
#
# == SUMMARY (Baseline vs Attacked on sampled 5%) ==
# mAP@0.50 : baseline=0.6172  |  attacked=0.6100  |  drop=0.0071
# mAP@0.50:0.95 : baseline=0.4320  |  attacked=0.4313  |  drop=0.0007
# Precision : baseline=0.8332  |  attacked=0.8265  |  drop=0.0067
# Recall : baseline=0.5176  |  attacked=0.5122  |  drop=0.0054
#
# Per-image proxy scores written to: /content/drive/MyDrive/MN-20-Credit/dota-yolo/de_three_pixel_attack/per_image_proxy_scores.csv
# Annotated baseline preds: /content/drive/MyDrive/MN-20-Credit/dota-yolo/de_three_pixel_attack/baseline/preds
# Annotated attacked preds: /content/drive/MyDrive/MN-20-Credit/dota-yolo/de_three_pixel_attack/attacked_preds
#
# Done.
